# %% [markdown]
# # Basic Syntax and Values - Practice Notebook
#
# This notebook provides practical exercises for learning Python's basic syntax: comments, variables, and print statements. All examples use finance and accounting contexts.

# %%
# Good naming examples in finance context
account_balance = 50000.00
revenue_current_month = 125000.50
payment_due_date = "2024-12-31"
is_invoice_paid = True

# Display account summary
print("Account Balance:", account_balance)
print("Current Month Revenue:", revenue_current_month)
print("Payment Due Date:", payment_due_date)
print("Invoice Paid:", is_invoice_paid)

# %% [markdown]
# ## 2. Best Practices for Variable Naming
#
# **Good practices:**
# - Use descriptive names (e.g., `account_balance` not `ab`)
# - Use lowercase with underscores (e.g., `total_revenue` not `TotalRevenue`)
# - Finance examples: `invoice_total`, `account_code`, `transaction_date`

# %%
# TODO: Create variables for payment information
# transaction_id = 
# payment_amount = 
# payment_status = 
# paid_by = 

# TODO: Print the variables

# %% [markdown]
# ### Practice Exercise 1: Create Variables
#
# Create variables to store payment information. Use clear, descriptive names.
#
# **Task:** Store the following information:
# - Transaction ID: 5001
# - Payment amount: 3500.75
# - Payment status: "Completed"
# - Paid by: "Customer ABC"

# %%
# Example: Store invoice information
invoice_number = 1001
invoice_amount = 2500.50
customer_name = "ABC Corporation"

# Display the stored values
print("Invoice Number:", invoice_number)
print("Amount:", invoice_amount)
print("Customer:", customer_name)

# %% [markdown]
# ## 1. Comments and Variables
#
# Comments start with `#` and explain code. Variables store values using meaningful names.

# %% [markdown]
# # Basic Syntax and Values - Practice Notebook
#
# This notebook provides practical exercises for learning Python's basic syntax: comments, variables, and print statements. All examples use finance and accounting contexts.

# %% [markdown]
# ## 1. Comments and Variables
#
# Comments start with `#` and explain code. Variables store values using meaningful names.

# %%
# Example: Store invoice information
invoice_number = 1001
invoice_amount = 2500.50
customer_name = "ABC Corporation"

# Display the stored values
print("Invoice Number:", invoice_number)
print("Amount:", invoice_amount)
print("Customer:", customer_name)

# %% [markdown]
# ### Practice Exercise 1: Create Variables
#
# Create variables to store payment information. Use clear, descriptive names.
#
# **Task:** Store the following information:
# - Transaction ID: 5001
# - Payment amount: 3500.75
# - Payment status: "Completed"
# - Paid by: "Customer ABC"

# %%
# TODO: Create variables for payment information
# transaction_id = 
# payment_amount = 
# payment_status = 
# paid_by = 

# TODO: Print the variables

# %% [markdown]
# ## 2. Best Practices for Variable Naming
#
# **Good practices:**
# - Use descriptive names (e.g., `account_balance` not `ab`)
# - Use lowercase with underscores (e.g., `total_revenue` not `TotalRevenue`)
# - Finance examples: `invoice_total`, `account_code`, `transaction_date`

# %%
# Good naming examples in finance context
account_balance = 50000.00
revenue_current_month = 125000.50
payment_due_date = "2024-12-31"
is_invoice_paid = True

# Display account summary
print("Account Balance:", account_balance)
print("Current Month Revenue:", revenue_current_month)
print("Payment Due Date:", payment_due_date)
print("Invoice Paid:", is_invoice_paid)
